# %%
import pandas as pd

# %%
retrieval_data = pd.read_csv("retrieval_testing_edit.csv")
generate_data = pd.read_csv("evaluation_edited.csv")

# %%
syn_data = pd.DataFrame(columns=["Retrieval Success?", "4o-mini eval", "o3-mini eval", "o1-mini eval", "3.5-turbo eval"])

# %%
syn_data['Retrieval Success?'] = retrieval_data['Success?']

# %%
syn_data['4o-mini eval'] = generate_data['4o-mini eval']
syn_data['o3-mini eval'] = generate_data['o3-mini eval']
syn_data['o1-mini eval'] = generate_data['o1-mini eval']
syn_data['3.5-turbo eval'] = generate_data['3.5-turbo eval']

# %%
syn_data[syn_data['Retrieval Success?'] == 'PARTIAL']
# Out:
#    Retrieval Success?  4o-mini eval  o3-mini eval  o1-mini eval  \
# 7             PARTIAL          True         False          True
# 17            PARTIAL         False         False         False
# 18            PARTIAL         False         False         False
# 20            PARTIAL         False          True          True
# 21            PARTIAL         False         False         False
# 24            PARTIAL         False         False         False
# 25            PARTIAL          True          True          True
# 27            PARTIAL          True          True          True
# 28            PARTIAL          True          True          True
# 34            PARTIAL          True          True          True
# 35            PARTIAL         False         False         False
# 36            PARTIAL          True          True          True
#
#     3.5-turbo eval
# 7             True
# 17           False
# 18           False
# 20            True
# 21           False
# ...

# %%
syn_data.to_csv("syn_data.csv")
